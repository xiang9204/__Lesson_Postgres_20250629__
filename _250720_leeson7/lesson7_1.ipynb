# %%
print("Hello python!")
print("以下是 python 的基本資料類型 (int, float, str, bool)")
15 #整數,(int)
15.0 #浮點數,(float)
"15.0" #字串,(str)
'15.0' #字串,(str)
True #布林值,(bool)
False #布林值,(bool)
# Out:
# Hello python!
# 以下是 python 的基本資料類型 (int, float, str, bool)
# False
