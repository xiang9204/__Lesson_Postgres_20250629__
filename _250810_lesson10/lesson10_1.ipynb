# %%
#請幫我建立一個 function
#連線至 postgres DB
#建立連線環境參數的樣版

import psycopg2


# 將環境變數做二次處理，不要將帳號密碼上傳到 github
from dotenv import load_dotenv
import os
load_dotenv()  # 載入 .env 檔案中的環境變數


def execute_query(connection, query):
    """
    執行 SQL 查詢並回傳結果
    connection: PostgreSQL 連線物件
    query: SQL 查詢字串
    """
    cursor = None
    try:
        cursor = connection.cursor()
        cursor.execute(query)
        result = cursor.fetchall()
        return result
    except psycopg2.Error as e:
        print(f"Error executing query: {e}")
        return None
    finally:
        if cursor:
            cursor.close()


def create_connection():
    conn = psycopg2.connect(               
        host=os.getenv("HOST"),
        dbname=os.getenv("DATABASE"),
        user=os.getenv("USER"),
        password=os.getenv("PASSWORD"),
        port="5432"
    )
    return conn

#main function
def main():
    conn = create_connection()

    if conn:
        print("Connection to PostgreSQL DB successful")

        query = """
        SELECT count(*) AS "總筆數"
        FROM "台鐵車站資訊"
        """
        print(f"SQL Query: {query}")
        result = execute_query(conn, query)
        if result:
            print(f"Query result: {result}")

        conn.close()
    else:
        print("Connection to PostgreSQL DB failed")

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[10], line 65
#      62         print("Connection to PostgreSQL DB failed")
#      64 if __name__ == "__main__":
# ---> 65     main()
#
# Cell In[10], line 46, in main()
#      45 def main():
# ---> 46     conn = create_connection()
#      48     if conn:
#      49         print("Connection to PostgreSQL DB successful")
#
# Cell In[10], line 35, in create_connection()
#      34 def create_connection():
# ---> 35     conn = psycopg2.connect(
#      36         host=os.getenv("HOST"),
#      37         dbname=os.getenv("DATABASE"),
#      38         user=os.getenv("USER"),
#      39         password=os.getenv("PASSWORD"),
#      40         port="5432"
#      41     )
#      42     return conn
#
# File /opt/conda/envs/pydev/lib/python3.10/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#     124     conn.cursor_factory = cursor_factory
#
# OperationalError: connection to server at "dpg-d2g8ccggjchc73ar6mtg-a.singapore-postgres.render.com" (13.214.97.86), port 5432 failed: FATAL:  database "chillee_sunday" does not exist
